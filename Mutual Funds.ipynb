# %%
import pandas as pd
import numpy as np

# %%
file_path = 'Historical Returns.xlsx'
df = pd.read_excel(file_path, skiprows=1)
df.columns = ["Scheme_Name", "Plan", "Category", "Crisil_Rating", "AuM", "1W", "1M", "3M", "6M", "YTD", "1Y", "2Y", "3Y", "5Y", "10Y"]

# %%
df
# Out:
#                                            Scheme_Name         Plan  \
# 0     Invesco India Contra Fund - Direct Plan - Growth  Direct Plan
# 1               SBI Contra Fund - Direct Plan - Growth  Direct Plan
# 2              SBI Contra Fund - Regular Plan - Growth      Regular
# 3    Franklin India ELSS Tax Saver Fund - Direct Pl...  Direct Plan
# 4          Franklin India ELSS Tax Saver Fund - Growth      Regular
# ..                                                 ...          ...
# 161            Axis Value Fund - Regular Plan - Growth      Regular
# 162  ICICI Prudential Value Discovery Fund - Direct...  Direct Plan
# 163     ICICI Prudential Value Discovery Fund - Growth      Regular
# 164                  JM Value Fund - (Direct) - Growth  Direct Plan
# 165                             JM Value Fund - Growth      Regular
#
#         Category Crisil_Rating       AuM      1W      1M      3M      6M  \
# 0    Contra Fund             3  18469.89  0.0090 -0.0350  0.0262  0.1970
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 166 entries, 0 to 165
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Scheme_Name    166 non-null    object
#  1   Plan           166 non-null    object
#  2   Category       166 non-null    object
#  3   Crisil_Rating  166 non-null    object
#  4   AuM            166 non-null    float64
#  5   1W             166 non-null    float64
#  6   1M             166 non-null    float64
#  7   3M             166 non-null    float64
#  8   6M             166 non-null    float64
#  9   YTD            166 non-null    float64
#  10  1Y             166 non-null    float64
#  11  2Y             166 non-null    float64
#  12  3Y             166 non-null    object
#  13  5Y             166 non-null    object
#  14  10Y            166 non-null    object
# dtypes: float64(8), object(7)
# memory usage: 19.6+ KB

# %%
df[['3Y', '5Y', '10Y']] = df[['3Y', '5Y', '10Y']].replace("-", np.nan)
df[['3Y', '5Y', '10Y']] = df[['3Y', '5Y', '10Y']].infer_objects(copy=False).astype(float)

# %%
df['3Y'] = df['3Y'].fillna(df['3Y'].median())
df['5Y'] = df['5Y'].fillna(df['5Y'].median())
df['10Y'] = df['10Y'].fillna(df['10Y'].median())

# %%
print(df[['3Y', '5Y', '10Y']].tail())
# Out:
#          3Y      5Y     10Y
# 161  0.1995  0.2367  0.1584
# 162  0.2208  0.2661  0.1656
# 163  0.2142  0.2593  0.1566
# 164  0.2512  0.2602  0.1876
# 165  0.2404  0.2504  0.1762

# %%
# Function to get top performers for each category
def get_top_performers(df, category, top_n=5):
    # Filter the data for the selected category
    category_df = df[df['Category'] == category]
    
    # Sorting by 3Y returns (you can also sort by 1Y, 5Y, etc., based on user preference)
    top_performers = category_df.sort_values(by='3Y', ascending=False).head(top_n)
    
    return top_performers[['Scheme_Name', 'Category', 'Crisil_Rating', 'AuM', '1Y', '3Y', '5Y']]
